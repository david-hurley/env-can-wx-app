# %%
import folium
from folium.plugins import MarkerCluster
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('station-metadata-processed.csv')
if df.Name.str.contains('ACTIV').any():
    print('y')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-89e9195426d3> in <module>
#       7     'name': 'First'
#       8 }]
# ----> 9 pd.DataFrame(data).str.contains('-')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
data = [{
    'x': df.Latitude,
    'y': df.Longitude,
    'mode': 'lines',
    'marker': {'color': 'XXXX'},
    'name': 'First'
}]

data.append({'x': 50, 
             'y': 60, 
             'mode': 'lines', 
             'marker': {'color': 'YYYY'},
             'name': 'Second'})
type(np.float64(60))
# Out:
# numpy.float64

# %%
len(df[df.Name.str.contains('')])
# Out:
# 8762

# %%
def haversine(lat1, lon1, lat2, lon2, to_radians=True, earth_radius=6371):
    """
    slightly modified version: of http://stackoverflow.com/a/29546836/2901002

    Calculate the great circle distance between two points
    on the earth (specified in decimal degrees or in radians)

    All (lat, lon) coordinates must have numeric dtypes and be of equal length.

    """
    if to_radians:
        lat1, lon1, lat2, lon2 = np.radians([lat1, lon1, lat2, lon2])

    a = np.sin((lat2-lat1)/2.0)**2 + \
        np.cos(lat1) * np.cos(lat2) * np.sin((lon2-lon1)/2.0)**2

    return earth_radius * 2 * np.arcsin(np.sqrt(a))

# %%
lat1,lon1 = np.radians([49,-123])
lat2,lon2 = np.radians([df.Latitude,df.Longitude])

a = np.sin((lat2-lat1)/2.0)**2 + \
    np.cos(lat1) * np.cos(lat2) * np.sin((lon2-lon1)/2.0)**2

t = 6371 * 2 * np.arcsin(np.sqrt(a))

# %%
df[t<100]
# Out:
#                             Name          Province Climate ID  Station ID  \
# 0                    ACTIVE PASS  BRITISH COLUMBIA    1010066          14
# 1                    ALBERT HEAD  BRITISH COLUMBIA    1010235          15
# 2         BAMBERTON OCEAN CEMENT  BRITISH COLUMBIA    1010595          16
# 3                     BEAR CREEK  BRITISH COLUMBIA    1010720          17
# 4                    BEAVER LAKE  BRITISH COLUMBIA    1010774          18
# ...                          ...               ...        ...         ...
# 1090      N VANCOUVER REDONDA DR  BRITISH COLUMBIA    110N6F5         697
# 1091            N VANC SONORA DR  BRITISH COLUMBIA    110N6FF         696
# 1092  NORTH VANCOUVER BLUE RIDGE  BRITISH COLUMBIA    110NFEQ         694
# 1093   NORTH VANCOUVER DOLLARTON  BRITISH COLUMBIA    110NFNF         695
# 1094            SURREY FLEETWOOD  BRITISH COLUMBIA    110S001       27198
#
#       Latitude  Longitude  Elevation  First Year  Last Year  HLY First Year  \
# ...

# %%
map.save('wx_location.html')

# %%
import plotly.express as px

fig = px.scatter_mapbox(df, lat="Latitude", lon="Longitude", hover_name="Name", hover_data=["Climate ID"],
                        color_discrete_sequence=["fuchsia"], zoom=3, height=300)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>
#
#
#             <div id="37ac9f1b-3c19-43ae-a09d-5ea65d9261f5" class="plotly-graph-div" style="height:300px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("37ac9f1b-3c19-43ae-a09d-5ea65d9261f5")) {
#                     Plotly.newPlot(
#                         '37ac9f1b-3c19-43ae-a09d-5ea65d9261f5',
# ...

# %%
pd.read_csv('https://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=1706&Year=2010&Month=10&Day=14&timeframe=1')
# Out:
#      Longitude (x)  Latitude (y)   Station Name  Climate ID         Date/Time  \
# 0          -114.44         62.46  YELLOWKNIFE A     2204100  2010-10-01 00:00
# 1          -114.44         62.46  YELLOWKNIFE A     2204100  2010-10-01 01:00
# 2          -114.44         62.46  YELLOWKNIFE A     2204100  2010-10-01 02:00
# 3          -114.44         62.46  YELLOWKNIFE A     2204100  2010-10-01 03:00
# 4          -114.44         62.46  YELLOWKNIFE A     2204100  2010-10-01 04:00
# ..             ...           ...            ...         ...               ...
# 739        -114.44         62.46  YELLOWKNIFE A     2204100  2010-10-31 19:00
# 740        -114.44         62.46  YELLOWKNIFE A     2204100  2010-10-31 20:00
# 741        -114.44         62.46  YELLOWKNIFE A     2204100  2010-10-31 21:00
# 742        -114.44         62.46  YELLOWKNIFE A     2204100  2010-10-31 22:00
# 743        -114.44         62.46  YELLOWKNIFE A     2204100  2010-10-31 23:00
#
# ...

# %%
df[['Latitude','Longitude']][0:5].values.tolist()
